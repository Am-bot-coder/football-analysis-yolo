# %% [markdown]
# Get Data

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="S0jDdUZ1imYM1uwwaqbO")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 1480.76it/s]

# %%
dataset.location
# Out:
# 'd:\\DL\\YOLO\\Football Goal Analysis\\Training\\football-players-detection-1'

# %%
import shutil
shutil.move(r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\train',
            r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\football-players-detection-1\train'
            )
shutil.move(r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\test',
            r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\football-players-detection-1\test'
            )
shutil.move(r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\valid',
            r'D:\DL\YOLO\Football Goal Analysis\Training\football-players-detection-1\football-players-detection-1\valid'
            )
# Out:
# 'D:\\DL\\YOLO\\Football Goal Analysis\\Training\\football-players-detection-1\\football-players-detection-1\\valid'

# %% [markdown]
# Training

# %% [markdown]
# >via Collab
